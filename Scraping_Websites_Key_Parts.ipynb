# %%
import requests, json
import numpy as np
from bs4 import BeautifulSoup
import pandas as pd
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
from urllib.parse import urlparse
headers = {'user-agent':'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36'}

# %%
def requests_retry(
    retries=3,  # 3 times try
    backoff_factor=0.3,
    status_forcelist=(500, 502,503,504),
    session=None,
):
    session = session or requests.Session()
    retry = Retry(
        total=retries,
        read=retries,
        connect=retries,
        backoff_factor=backoff_factor,
        status_forcelist=status_forcelist,
    )
    adapter = HTTPAdapter(max_retries=retry)
    session.mount('http://', adapter)
    session.mount('https://', adapter)
    return session

# %%
def get_soup_handle(url):
    r = requests_retry().get(url, headers=headers, timeout=10)
    c= r.content
    soup=BeautifulSoup(c,"html.parser")
    return soup

# %%
#### get about links
def get_about_links(soup,frame,home_url):
    
    urls = soup.find_all("a")
    about_urls = []
    for url in urls:
        if 'about' in str(url.get("href")).lower()  and frame == 0:
#             print("in about non frame part")
            about_urls.append(url.get("href"))
            
        if 'about' in str(url.get("href")).lower()  and frame == 1:
#             print("in about frame part")
            about_urls.append(home_url + url.get("href"))

#             print(url.get("href"))
    return about_urls

# %%
#### get prod and service links
def get_service_product_links(soup,frame,home_url):

    urls = soup.find_all("a")
    about_urls = []
    for url in urls:
        if frame == 0 and ('service' in str(url.get("href")).lower() or 'product' in str(url.get("href")).lower() or 'offerings' in str(url.get("href")).lower() or 'item' in str(url.get("href")).lower()):
#             print("in product non frame part")
            about_urls.append(url.get("href"))

        if frame == 1 and ('service' in str(url.get("href")).lower() or 'product' in str(url.get("href")).lower() or 'offerings' in str(url.get("href")).lower() or 'item' in str(url.get("href")).lower()):
#             print("in product frame part")
            about_urls.append(home_url + url.get("href"))

        #             print(url.get("href"))
    return about_urls

# %%
def get_text(soup):
    tags = ['p','ul']
    full_text = ""
    for tag in tags:
        extracts = soup.find_all(tag)
        for extract in extracts:
            full_text = str(full_text) + str(extract.text)
    if full_text == "":
        full_text = "Null scraped"
    return full_text

# %%
def get_content(home_soup,home_url,frame=0):
    
    dict_web = {}  
    ## get home page text
    home_page_text = get_text(home_soup)
    dict_web["home"] = home_page_text

#     ## get meta text
#     meta_text = get_meta(home_soup)
#     dict_web["meta"] = meta_text

    ## get about links and text
    about_urls = get_about_links(home_soup,frame,home_url)
    about_page_text = ""
    prod_page_text = ""
    if len(about_urls) > 0:
        about_urls = list(set(about_urls))
        for url in about_urls:
            try:
                soup = get_soup_handle(url)
                about_page_text = about_page_text + get_text(soup)
            except:
                continue
        if about_page_text == "":
            about_page_text = "Null scraped"

    dict_web["about"] = about_page_text

        ## get product, service and offerings links and text
    prod_urls = get_service_product_links(home_soup,frame,home_url)
    if len(prod_urls) > 0:
        prod_urls = list(set(prod_urls))
        for url in prod_urls:
            try:
                soup = get_soup_handle(url)
                prod_page_text = prod_page_text + get_text(soup)
            except:
                continue
        if prod_page_text == "":
            prod_page_text = "Null scraped"

    dict_web["prod"] = prod_page_text
    
        
    return dict_web

# %%
def get_total_content(url):
#     print("requesting content")
    try:
        r=requests.get(url, headers=headers, timeout=10)
    except:
#         print(url)
#         print("exiting")
        content = {}
        content['about'] = "url not reachable"
        content['home'] = "url not reachable"
        content['prod'] = "url not reachable"
#         content['meta'] = "url not reachable"
        return content
    c= r.content
#     print("content collected")
    soup=BeautifulSoup(c,"html.parser")
#     print("got soup handle")
    try:
            #### handle as per frame
#         print("entering")
        frame = soup.frame.extract()
        frame_link = frame.get("src")
        r=requests.get(frame_link, headers=headers, timeout=10)
        c= r.content
        frame_soup=BeautifulSoup(c,"html.parser")
#         print("fetching frame contents")
        content = get_content(frame_soup,frame_link,frame=1)
    except:
        #### handle as normal
#         print("fetching normal contents")
        content = get_content(soup,url,frame=0)
    return content

# %%
### read data

# df = pd.read_excel("C:/Users/arvind.baranwal/Downloads/starstone_more_data_for_web_scrape.xlsx")
# data = pd.read_json("companies_with_website.json",lines=True)
with open('C:/Users/arvind.baranwal/Downloads/website_to_NAICS/companies_with_website.json') as json_file:  
    data = json.load(json_file)
# data = json.loads("companies_with_website.json")

# %%
len(data)
# Out:
# 848284

# %%
data = data[420000:848284]

# %%
len(data)
# Out:
# 428284

# %%
urls = []
for i in range(0,len(data)):
    urls.append(data[i]['website_1'])

# %%
len(urls)
# Out:
# 428284

# %%
for i in range(0,len(urls)):
    urls[i] = "http://" + urls[i]

# %%
urls
# Out:
# ['http://www.metalmag.com',
#  'http://www.cm201u.org',
#  'http://www.laurathompsondesign.net',
#  'http://www.rafscleaning.com',
#  'http://www.adamsservices.com',
#  'http://www.mackenzieco.com',
#  'http://www.royalbankpa.com',
#  'http://www.pinkerton.com',
#  'http://www.pacificcoastcopperrepipe.com',
#  'http://www.mcdavid.com',
#  'http://www.1mbh.com',
#  'http://www.thepismobeachhotel.com',
#  'http://www.avalon.net',
#  'http://www.ci.wixom.mi.us',
#  'http://www.beckerperio.com',
#  'http://www.shelby-group.com',
#  'http://www.williamstown.k12.ma.us',
#  'http://www.gregorypoole.com',
#  'http://www.wakemed.org',
#  'http://www.keywestlawyer.com',
#  'http://www.vcsd.org',
#  'http://www.schaumburgarchitects.com',
#  'http://www.winstonpublishing.com',
#  'http://www.leealanbryant.com',
#  'http://www.kofflerboats.com',
#  'http://www.tlsinc.com',
#  'http://www.dillard.edu',
#  'http://www.booksnmagz.com',
#  'http://www.univision.com',
#  'http://www.ccnsy.com',
#  'http://www.hermosawaveinternet.com',
#  'http://www.rossstores.com',
#  'http://www.rebeccanurse.org',
#  'http://www.ramcell.net',
#  'http://www.synergetics.com',
#  'http://www.biocsi.com',
#  'http://www.thepattersoncompany.com',
#  'http://www.krausmanagement.com',
#  'http://www.colossus-lp.com',
#  'http://www.islandone.com',
#  'http://www.kirbyvillecisd.org',
#  'http://www.ksn.com',
#  'http://www.laibrestoration.com',
#  'http://www.horizonaudio.com',
#  'http://www.waileatennis.com',
#  'http://www.drdooley.com',
#  'http://www.hartrestoration.com',
#  'http://www.pmlmanagement.com',
#  'http://www.savory-snacks.com',
#  'http://www.films.com',
#  'http://www.quadrasinc.com',
#  'http://www.alwardconstruction.com',
#  'http://www.redcardinal.com',
#  'http://www.desertvista.org',
#  'http://www.cnsw.com',
#  'http://www.vtrader.net',
#  'http://www.gfprototype.com',
#  'http://www.colonialgc.com',
#  'http://www.seesinterpreters.com',
#  'http://www.pfsusa.net',
#  'http://www.svpanthers.org',
#  'http://www.csi-kc.com',
#  'http://www.dextermaine.org',
#  'http://www.homestylepizza.com',
#  'http://www.soundfishing.com',
#  'http://www.collier.k12.fl.us',
#  'http://www.berkeley-public.org',
#  'http://www.bodycraft.com',
#  'http://www.tfcaldwell.com',
#  'http://www.adtnuclear.com',
#  'http://www.trapaniorthodontics.com',
#  'http://www.mdcromani.com',
#  'http://www.berkshirechase.com',
#  'http://www.thewesleycommunity.com',
#  'http://www.messa.org',
#  'http://www.am-inc.com',
#  'http://www.adr.org',
#  'http://www.texascity.isd.tenet.edu',
#  'http://www.tupelotool.com',
#  'http://www.beztak.com',
#  'http://www.systemsynergy.com',
#  'http://www.kasrugs.com',
#  'http://www.huntingtonnannies.com',
#  'http://www.neptuneplumbing.com',
#  'http://www.skipjacks.com',
#  'http://www.dggink.com',
#  'http://www.libertycad.com',
#  'http://www.prudentialmprealty.com',
#  'http://www.juliabfee.com',
#  'http://www.westernsizzlin.com',
#  'http://www.motorcarstoyota.com',
#  'http://www.kisslingorganization.com',
#  'http://www.arborhilltreefarm.com',
#  'http://www.newhumormfg.com',
#  'http://www.macnexus.org',
#  'http://www.mesh5.com',
#  'http://www.muellermachine.com',
#  'http://www.sheldonshobbies.com',
#  'http://www.perceptive-inc.com',
#  'http://www.argonautbookshop.com',
#  'http://www.1800theeagle.com',
#  'http://www.gaa-ae.com',
#  'http://www.globalppi.com',
#  'http://www.lyftym.com',
#  'http://www.cardinalridgecbrf.com',
#  'http://www.weed-man.com',
#  'http://www.burbank.k12.ca.us',
#  'http://www.poppypatch.org',
#  'http://www.montonesystems.com',
#  'http://www.lawsuites.net',
#  'http://www.noahs-ark.org',
#  'http://www.childdevelopment.org',
#  'http://www.quikrete.com',
#  'http://www.affinitygroup.com',
#  'http://www.oxnardsd.frank.org',
#  'http://www.browerville.k12.mn.us',
#  'http://www.surfex.com',
#  'http://www.landofcanaan.com',
#  'http://www.badgermutual.com',
#  'http://www.nlcargo.com',
#  'http://www.cherokeetribune.com',
#  'http://www.kato-eng.com',
#  'http://www.eurosport.com',
#  'http://www.setoncincinnati.org',
#  'http://www.karder.com',
#  'http://www.royalathleticclub.com',
#  'http://www.perceptionbuilders.com',
#  'http://www.econar.com',
#  'http://www.dsande.com',
#  'http://www.ameritelinc.com',
#  'http://www.surovekgallery.com',
#  'http://www.panhandlerealty.com',
#  'http://www.themufflerexpress.com',
#  'http://www.starprograms.org',
#  'http://www.islanddivers.com',
#  'http://www.connellresources.com',
#  'http://www.methodist.org',
#  'http://www.permarsecurity.com',
#  'http://www.lookfx.com',
#  'http://www.chaifetzandschreiber.com',
#  'http://www.fwbt.net',
#  'http://www.copelandsurveying.com',
#  'http://www.columbiacitypolice.us',
#  'http://www.cbiz.com',
#  'http://www.fidelitybankmn.com',
#  'http://www.sheriff.barrowga.org',
#  'http://www.clevelandtexas.com',
#  'http://www.adwarvideo.com',
#  'http://www.stgenevievechurch.com',
#  'http://www.coac.org',
#  'http://www.transland.com',
#  'http://www.electronicwarehouse.com',
#  'http://www.aandbgifts.com',
#  'http://www.latimerdentalarts.com',
#  'http://www.enerfab.com',
#  'http://www.rctheberge.com',
#  'http://www.kentamlinrealty.com',
#  'http://www.escalate.com',
#  'http://www.granitecitytool.com',
#  'http://www.mindseedrecords.com',
#  'http://www.bellflowervet.com',
#  'http://www.kingsinnmotel.com',
#  'http://www.dinair.com',
#  'http://www.myriaminteriors.com',
#  'http://www.shirleyjeanschmidt.com',
#  'http://www.write-a-webpage.com',
#  'http://www.dolancreations.com',
#  'http://www.security-controls.com',
#  'http://www.francisschool.com',
#  'http://www.bgcofsparta.org',
#  'http://www.brooke.com',
#  'http://www.cogencysoft.com',
#  'http://www.maggettielam.com',
#  'http://www.graycary.com',
#  'http://www.aicsolutionsinc.com',
#  'http://www.ambook.org',
#  'http://www.asaiatm.com',
#  'http://www.oleyvalley.com',
#  'http://www.bobsfoam.com',
#  'http://www.floridashirdisai.org',
#  'http://www.cityofwhitefish.org',
#  'http://www.1inhealth.com',
#  'http://www.kindermagic.com',
#  'http://www.markheardfuel.com',
#  'http://www.lni.wa.gov',
#  'http://www.comcare.org',
#  'http://www.horstbrothers.com',
#  'http://www.lynk.org',
#  'http://www.powershack.com',
#  'http://www.mtwestret.com',
#  'http://www.diamondrealtyoftn.com',
#  'http://www.groupunderwriters.com',
#  'http://www.scott.k12.ky.us',
#  'http://www.wanette.k12.ok.us',
#  'http://www.qresources.com',
#  'http://www.winfieldgrp.com',
#  'http://www.stjoeeng.com',
#  'http://www.doorking.com',
#  'http://www.cyberschool-milwaukee.org',
#  'http://www.qualitytest.com',
#  'http://www.wallsrx.com',
#  'http://www.emdnet.org',
#  'http://www.easternenvironmental.com',
#  'http://www.oam-inc.com',
#  'http://www.telemaxx.com',
#  'http://www.actech.cc',
#  'http://www.failsafevalves.com',
#  'http://www.isasw.org',
#  'http://www.kush.com',
#  'http://www.nenfhs.org',
#  'http://www.moonstonehotels.com',
#  'http://www.wejoysing.com',
#  'http://www.salvy.com',
#  'http://www.breakersresort.com',
#  'http://www.yakimafmc.org',
#  'http://www.promats.com',
#  'http://www.mason.k12.ky.us',
#  'http://www.lemone.com',
#  'http://www.abex.com',
#  'http://www.homefeedback.com',
#  'http://www.mjpsystems.com',
#  'http://www.forministry.com/30147cogop',
#  'http://www.earthtek.com',
#  'http://www.beacon-light.org',
#  'http://www.hanksicecream.com',
#  'http://www.masspro.org',
#  'http://www.rentalworlds.com',
#  'http://www.firstinter.net',
#  'http://www.narcisosprinting.com',
#  'http://www.fauquiercounty.gov',
#  'http://www.greencounty.com',
#  'http://www.parkcliffe.com',
#  'http://www.controlsource.com',
#  'http://www.thasegawausa.com',
#  'http://www.hncsearch.com',
#  'http://www.smccmonroe.com',
#  'http://www.foodperspectives.com',
#  'http://www.flintaero.com',
#  'http://www.sparkyandclarks.com',
#  'http://www.mwdevelopment.com',
#  'http://www.freedplasticsurgery.com',
#  'http://www.iavaronebros.com',
#  'http://www.jbciengineers.com',
#  'http://www.cbenson.com',
#  'http://www.mountech.com',
#  'http://www.featherlite.com',
#  'http://www.domanusmasonry.com',
#  'http://www.mckaysbakery.com',
#  'http://www.artcrest.com',
#  'http://www.pneumadyne.com',
#  'http://www.augustamortgage.com',
#  'http://www.msasnow.org',
#  'http://www.kurelisinteriors.com',
#  'http://www.patterncentral.com',
#  'http://www.hfhcpa.com',
#  'http://www.benefitmgt.com',
#  'http://www.athensfederal.com',
#  'http://www.leesmoving.com',
#  'http://www.pineriver.k12.mi.us',
#  'http://www.randbsales.com',
#  'http://www.hrhvegas.com',
#  'http://www.ohgalvanizedtube.com',
#  'http://www.amsmidwst.com',
#  'http://www.preferredsourcing.com',
#  'http://www.insight-interactive.com',
#  'http://www.metrogreens.com',
#  'http://www.sixriverssolar.com',
#  'http://www.anorganizedsolution.com',
#  'http://www.bbcofm.com',
#  'http://www.ekonpowdercoating.com',
#  'http://www.plasto-tech.com',
#  'http://www.aidsaction.org',
#  'http://www.allfreightshipping.com',
#  'http://www.lexcem.org',
#  'http://www.marketrealty.com',
#  'http://www.grumpsgrill.com',
#  'http://www.fiberartshop.com',
#  'http://www.spaorlando.com',
#  'http://www.ugadogs.com',
#  'http://www.orionflightservices.com',
#  'http://www.newcanaanoil.com',
#  'http://www.edgemont.org',
#  'http://www.manitobacorp.com',
#  'http://www.logiclandusa.com',
#  'http://www.kianaskakes.com',
#  'http://www.capatriots.org',
#  'http://www.verrerie-goods.com',
#  'http://www.strachota.com',
#  'http://www.brushman.com',
#  'http://www.ceocast.com',
#  'http://www.adrubber.com',
#  'http://www.hotelsarizona.com',
#  'http://www.pyco.com',
#  'http://www.hjricerealty.com',
#  'http://www.krgenterprises.com',
#  'http://www.erumc.org',
#  'http://www.madisonradiology.com',
#  'http://www.waysideumc.org',
#  'http://www.talkaboutinc.com',
#  'http://www.mississippiconcrete.com',
#  'http://www.cathedralbasilica.org',
#  'http://www.highfields.org',
#  'http://www.doolans.com',
#  'http://www.etisvs.com',
#  'http://www.waynflete.org',
#  'http://www.ardmorecity.com',
#  'http://www.russellcorp.com',
#  'http://www.toagosei.net',
#  'http://www.irlfunds.org',
#  'http://www.southwestent.com',
#  'http://www.smd-llc.com',
#  'http://www.horizonsrealestate.com',
#  'http://www.aurorahealthcare.org',
#  'http://www.obryan.biz',
#  'http://www.ohcu.org',
#  'http://www.glasscraft.net',
#  'http://www.wasco.k12.ca.us',
#  'http://www.jvskc.org',
#  'http://www.infraredanalysisinc.com',
#  'http://www.kolemeth.com',
#  'http://www.stan-the-man.com',
#  'http://www.thesausagefactory.com',
#  'http://www.unityatthelake.org',
#  'http://www.pelletierrealty.com',
#  'http://www.lakelandequipment.com',
#  'http://www.mclaughlinonline.com',
#  'http://www.schwerdtel.com',
#  'http://www.driftwoodresort.com',
#  'http://www.duckcreek.com',
#  'http://www.butchnnellies.com',
#  'http://www.na.org',
#  'http://www.shawncotten.com',
#  'http://www.cityofchanuteks.com',
#  'http://www.lansingschools.org',
#  'http://www.ci.milpitas.ca.gov',
#  'http://www.photolaboratory.com',
#  'http://www.debrafranklaw.com',
#  'http://www.evolutionssalondayspa.com',
#  'http://www.firstnightcols.com',
#  'http://www.vertisinc.com',
#  'http://www.data-call.com',
#  'http://www.remax-boxfordma.com',
#  'http://www.angelos-pizza.com',
#  'http://www.bostonreps.com',
#  'http://www.saugatuckcity.com',
#  'http://www.gcmlaw.com',
#  'http://www.ahsupply.net',
#  'http://www.jafra.com',
#  'http://www.justgowest.com',
#  'http://www.srmhc.org',
#  'http://www.turbotuneusltd.com',
#  'http://www.zupans.com',
#  'http://www.weproduce.com',
#  'http://www.sfis2.com',
#  'http://www.acico.com',
#  'http://www.hubgroup.com',
#  'http://www.chuaphucsinh.org',
#  'http://www.southvalleyms.net',
#  'http://www.primepower.com',
#  'http://www.ritzcarlton.com',
#  'http://www.clearwatercounseling.com',
#  'http://www.pharmaports.com',
#  'http://www.abbinc.com',
#  'http://www.pdfp.com',
#  'http://www.bcsrealtor.com',
#  'http://www.greniersphoto.com',
#  'http://www.ktron.com',
#  'http://www.villa-reale.com',
#  'http://www.northstar-centre.com',
#  'http://www.stpaultheapostlechurch.org',
#  'http://www.centralprintingwv.com',
#  'http://www.aero-material.com',
#  'http://www.loraxenv.com',
#  'http://www.concordebanquets.com',
#  'http://www.colonial.net',
#  'http://www.improveitusa.com',
#  'http://www.ajfastener.com',
#  'http://www.suckle.net',
#  'http://www.mediaspot.com',
#  'http://www.alliedfirst.com',
#  'http://www.nowcare.com',
#  'http://www.winchestergc.com',
#  'http://www.wm.com',
#  'http://www.architectsunlimited.com',
#  'http://www.wwftruss.com',
#  'http://www.tragara.com',
#  'http://www.corporatecare.com',
#  'http://www.strsd.southwick.ma.us',
#  'http://www.hopkinsmd.com',
#  'http://www.drnix.com',
#  'http://www.heavyglass.com',
#  'http://www.dreamsofparadisegallery.net',
#  'http://www.toolsinc.com',
#  'http://www.adelicatebalance.net',
#  'http://www.ageefilms.org',
#  'http://www.newlifereformed.org',
#  'http://www.nga.com',
#  'http://www.sparkmon.com',
#  'http://www.coveredbridgeacademy.com',
#  'http://www.edmondsplazaflorist.com',
#  'http://www.roaringspringstore.com',
#  'http://www.dosmanos.com',
#  'http://www.calrehab.org',
#  'http://www.mec.ms',
#  'http://www.durvet.com',
#  'http://www.scedc.org',
#  'http://www.carsonmfg.net',
#  'http://www.chindex.com',
#  'http://www.fccservices.org',
#  'http://www.commercialartband.com',
#  'http://www.bmturf.com',
#  'http://www.littlenorway.com',
#  'http://www.cottagegroveonline.com',
#  'http://www.farmfresh.com',
#  'http://www.rochesterabrasives.com',
#  'http://www.lidskylaw.com',
#  'http://www.kaleidahealth.org',
#  'http://www.richlund.com',
#  'http://www.emflux.com',
#  'http://www.co.marin.ca.us',
#  'http://www.freedomcheerleading.com',
#  'http://www.insul-8.com',
#  'http://www.bridalgowns.net',
#  'http://www.woodsassoc.com',
#  'http://www.mukuni.com',
#  'http://www.abbeyfoodandbar.com',
#  'http://www.awarehouseonwheels.com',
#  'http://www.fundadmin.com',
#  'http://www.klxcomputergroup.com',
#  'http://www.mormon.org',
#  'http://www.northernhillschurch.org',
#  'http://www.fay.com',
#  'http://www.westminstercollege.edu',
#  'http://www.redlurered.com',
#  'http://www.ucnb.com',
#  'http://www.aaaom.org',
#  'http://www.worldmgmt.com',
#  'http://www.franklinfarm.com',
#  'http://www.audiovisionsetc.com',
#  'http://www.thedunhillcompany.com',
#  'http://www.sgaonline.com',
#  'http://www.drautorestyle.com',
#  'http://www.coxstudio.com',
#  'http://www.mjcomm.com',
#  'http://www.ccahosp.com',
#  'http://www.bobshvac.com',
#  'http://www.crossmfg.com',
#  'http://www.belldesigncompany.com',
#  'http://www.baileyprintinginc.com',
#  'http://www.northcoastpools.com',
#  'http://www.willametteturf.com',
#  'http://www.vivian-stlouis.com',
#  'http://www.stcnetcom.com',
#  'http://www.brookstone.com',
#  'http://www.karenbradford.com',
#  'http://www.lrradioworks.com',
#  'http://www.pacificatelier.com',
#  'http://www.cpeck.com',
#  'http://www.30eastmain.com',
#  'http://www.cpuexhibits.com',
#  'http://www.duluthrotary.org',
#  'http://www.zunkercrane.com',
#  'http://www.enxco.com',
#  'http://www.foothillfunding.com',
#  'http://www.hudsongreenway.state.ny.us',
#  'http://www.celebrationcruising.com',
#  'http://www.flagstonegroup.com',
#  'http://www.msgl.com',
#  'http://www.npwtradelaw.com',
#  'http://www.conomos.com',
#  'http://www.lazydaysmarina.com',
#  'http://www.njys.org',
#  'http://www.ltsd.k12.pa.us',
#  'http://www.bartholomewco.com',
#  'http://www.beyondbliss.com',
#  'http://www.youngstruckcenter.com',
#  'http://www.health.state.ok.us',
#  'http://www.flite-tours.com',
#  'http://www.carthage.k12.mo.us',
#  'http://www.emedicalsolutions.net',
#  'http://www.oxford.k12.pa.us',
#  'http://www.paulsmarine.com',
#  'http://www.mntechnology.com',
#  'http://www.mesamobilehomes.com',
#  'http://www.scripturesforamerica.org',
#  'http://www.pavtech.com',
#  'http://www.vac-u-clamp.com',
#  'http://www.zalcolabs.com',
#  'http://www.theautoexpo.com',
#  'http://www.rennoc.com',
#  'http://www.rushcopley.com',
#  'http://www.randconsulting.com',
#  'http://www.barker-ewing.com',
#  'http://www.meridianautowrecking.com',
#  'http://www.jetaviation.com',
#  'http://www.bestact.com',
#  'http://www.jonesplastic.com',
#  'http://www.greatlakesindustrialfansandblowers.c',
#  'http://www.blygoldamerica.com',
#  'http://www.wallace1.com',
#  'http://www.allstonvillage.com',
#  'http://www.insurit.com',
#  'http://www.bowlingworldonline.com',
#  'http://www.nationalcattlecongress.com',
#  'http://www.windycitypopcorn.com',
#  'http://www.science-fair-supply.com',
#  'http://www.colterelectric.com',
#  'http://www.dynamichomes.com',
#  'http://www.projo.com',
#  'http://www.ritacorp.com',
#  'http://www.micucci.com',
#  'http://www.sumnaz.org',
#  'http://www.iowatitle.com',
#  'http://www.haasbodyshop.com',
#  'http://www.stromaviation.com',
#  'http://www.greatlakespt.com',
#  'http://www.exodusrecovery.com',
#  'http://www.ims.com',
#  'http://www.maspeth.com',
#  'http://www.regalia.com',
#  'http://www.coshoctontribune.com',
#  'http://www.gfhardwoods.com',
#  'http://www.meriwether.k12.ga.us',
#  'http://www.fwservice.com',
#  'http://www.fultoncountyoh.com',
#  'http://www.fleeger.com',
#  'http://www.mtnmistcabins.com',
#  'http://www.yesteryearcyclery.com',
#  'http://www.altexindustriesinc.com',
#  'http://www.avondaledentalcenter.com',
#  'http://www.okc.gov',
#  'http://www.journalregister.com',
#  'http://www.usroasterie.com',
#  'http://www.chabadofdallas.com',
#  'http://www.millipore.com',
#  'http://www.tempaco.com',
#  'http://www.capital-connections.com',
#  'http://www.lesauermachine.com',
#  'http://www.herbchambers.com',
#  'http://www.hatcherchurch.org',
#  'http://www.sassafrasrestaurant.com',
#  'http://www.avlgroup.com',
#  'http://www.countrytowne.net',
#  'http://www.schoolnotes.com',
#  'http://www.bredemann.com',
#  'http://www.consortiumcommunications.com',
#  'http://www.ci.gatlinburg.tn.us',
#  'http://www.alexandriaarearealty.com',
#  'http://www.denon.com',
#  'http://www.gmgww.com',
#  'http://www.kemmeusa.com',
#  'http://www.stclaremedical.org',
#  'http://www.bbmofokc.com',
#  'http://www.visualdevelopment.com',
#  'http://www.almillerroofing.com',
#  'http://www.zolakeller.com',
#  'http://www.johnqssteakhouse.com',
#  'http://www.riceroselaw.com',
#  'http://www.riverbank.biz',
#  'http://www.fircgroup.com',
#  'http://www.xritephoto.com',
#  'http://www.forministry.com',
#  'http://www.easterninternationalrealty.com',
#  'http://www.gelinashvac.com',
#  'http://www.audiosystemsfl.com',
#  'http://www.ficocellos.com',
#  'http://www.birchridgeresort.com',
#  'http://www.kimfalk.com',
#  'http://www.keybiscayne.fl.gov',
#  'http://www.fletcherheald.com',
#  'http://www.combinedrealty.com',
#  'http://www.destijlengineering.com',
#  'http://www.smithmusic.com',
#  'http://www.excelmotorsports.com',
#  'http://www.ateamphoto.com',
#  'http://www.flmcorp.com',
#  'http://www.jhtechnology.com',
#  'http://www.frontierenergy.org',
#  'http://www.tribesalon.com',
#  'http://www.teamextenda.com',
#  'http://www.patuxentcompanies.com',
#  'http://www.taboorestaurant.com',
#  'http://www.ride-away.com',
#  'http://www.holberttrailers.com',
#  'http://www.wnfg.com',
#  'http://www.healthweb1.com',
#  'http://www.ganisrael.com',
#  'http://www.us.kpmg.com',
#  'http://www.maurymw.com',
#  'http://www.manzodental.com',
#  'http://www.lingling.com',
#  'http://www.flightsafetyonline.com',
#  'http://www.articfalls.com',
#  'http://www.sierracustom.com',
#  'http://www.774food.com',
#  'http://www.thelastchancewinery.com',
#  'http://www.jctcu.org',
#  'http://www.markkusnerco.com',
#  'http://www.westphaliaum.org',
#  'http://www.nycc.edu',
#  'http://www.auroraoh.com',
#  'http://www.jolleyasset.com',
#  'http://www.dafferorgans.com',
#  'http://www.huntersalescorp.com',
#  'http://www.meanstreet.net',
#  'http://www.bwaycorp.com',
#  'http://www.sandy-city.net',
#  'http://www.coexgroup.com',
#  'http://www.parkingnetwork.net',
#  'http://www.midamericadialysis.com',
#  'http://www.nplanner.com',
#  'http://www.etcos.com',
#  'http://www.sageconstruction.com',
#  'http://www.esprecision.com',
#  'http://www.faustrealestate.com',
#  'http://www.signatureapartments.net',
#  'http://www.walnutvalley.k12.ca.us',
#  'http://www.cyber-struct.com',
#  'http://www.forplayshoes.com',
#  'http://www.admworld.com',
#  'http://www.crisisprevention.com',
#  'http://www.smithelectric.com',
#  'http://www.usalm.com',
#  'http://www.bridgesresort.com',
#  'http://www.eyecarecarolinas.com',
#  'http://www.hermeslawfirm.com',
#  'http://www.mediarightgirls.com',
#  'http://www.byoruksijang.com',
#  'http://www.albertsplastering.com',
#  'http://www.hallmark.com',
#  'http://www.tekni-plex.com',
#  'http://www.bendcable.net',
#  'http://www.starthrower.com',
#  'http://www.aim-soft.com',
#  'http://www.metropolitanreporters.com',
#  'http://www.sd54.org',
#  'http://www.geolfossilversmiths.com',
#  'http://www.jeffcomo.org',
#  'http://www.bjwrr.org',
#  'http://www.webmis.com',
#  'http://www.kempkey.com',
#  'http://www.debankers.com',
#  'http://www.aegisrealtyconsultants.com',
#  'http://www.magnoliaisd.org',
#  'http://www.manning-construction.com',
#  'http://www.platt.com',
#  'http://www.dtcpublishing.com',
#  'http://www.vdmlaw.com',
#  'http://www.cafetututango.com',
#  'http://www.the-river.org',
#  'http://www.paycor.com',
#  'http://www.carlisle.com',
#  'http://www.trentonsoupkitchen.org',
#  'http://www.faircrest.com',
#  'http://www.springcreekoutfitter.com',
#  'http://www.co.hillsdale.mi.us',
#  'http://www.coptervision.com',
#  'http://www.answeringunlimited.com',
#  'http://www.ingersollinsurance.com',
#  'http://www.art4business.com',
#  'http://www.mitchell-drilling.com',
#  'http://www.lavender-gc.com',
#  'http://www.holyfamily.com',
#  'http://www.cosmeticlaser.com',
#  'http://www.vansliquor.com',
#  'http://www.elizabethshouse.org',
#  'http://www.insuranceplusagency.com',
#  'http://www.sacent.com',
#  'http://www.nustats.com',
#  'http://www.theallergyshop.com',
#  'http://www.fleshlight.com',
#  'http://www.exclusivedevelopment.net',
#  'http://www.healthback.com',
#  'http://www.ymcacolumbus.org',
#  'http://www.crownconsulting.net',
#  'http://www.x-m-s.com',
#  'http://www.hubnerseed.com',
#  'http://www.brainerdsportsandmarine.com',
#  'http://www.westvalleypetlodge.com',
#  'http://www.ozarktech.com',
#  'http://www.cozy-acres.com',
#  'http://www.palmbeachcta.org',
#  'http://www.qasoftware.com',
#  'http://www.millermoving.com',
#  'http://www.berksmontcamping.com',
#  'http://www.glessranch.com',
#  'http://www.critterbeach.com',
#  'http://www.charleswilliambush.com',
#  'http://www.vatastebuds.com',
#  'http://www.montwood.org',
#  'http://www.cyprustradeny.org',
#  'http://www.adwillis.com',
#  'http://www.carterelectricinc.com',
#  'http://www.suntravelagency.com',
#  'http://www.pgcps.org',
#  'http://www.pickwickantiques.com',
#  'http://www.thebannettgroup.com',
#  'http://www.westsouthwest.com',
#  'http://www.saporcafe.com',
#  'http://www.johnson-construction.com',
#  'http://www.adzrresults.com',
#  'http://www.rlhcpa.com',
#  'http://www.laufer.com',
#  'http://www.euclidtravel.com',
#  'http://www.holidaytouch.com',
#  'http://www.phenomixcorp.com',
#  'http://www.goldencirclerealty.com',
#  'http://www.captainsorders.com',
#  'http://www.brokenbowrecords.com',
#  'http://www.bostonaircontrols.com',
#  'http://www.co.pg.md.us',
#  'http://www.mhrplus.com',
#  'http://www.adonaservices.com',
#  'http://www.intramarinc.com',
#  'http://www.12thmanfoundation.com',
#  'http://www.emersonhubbardschools.org',
#  'http://www.vincel.com',
#  'http://www.gardnertrucking.com',
#  'http://www.mankatoimplement.com',
#  'http://www.etiprofessionals.com',
#  'http://www.giltron.com',
#  'http://www.carbonado.k12.wa.us',
#  'http://www.starlineindustries.com',
#  'http://www.holttravel.com',
#  'http://www.ccps.org',
#  'http://www.benchmarkbank.com',
#  'http://www.pvhn.com',
#  'http://www.roadandtrackmotorsport.com',
#  'http://www.oscar-wilson.com',
#  'http://www.lltech.com',
#  'http://www.martexcircuits.com',
#  'http://www.exelinn.com',
#  'http://www.cookandcraft.com',
#  'http://www.finagleabagel.com',
#  'http://www.mhm-services.com',
#  'http://www.co.clark.nv.us',
#  'http://www.milltownps.org',
#  'http://www.wardwell.com',
#  'http://www.breproperties.com',
#  'http://www.jmwelding.com',
#  'http://www.jellystonewa.com',
#  'http://www.optimacontrols.com',
#  'http://www.buildersappraisal.com',
#  'http://www.co.monroe.in.us',
#  'http://www.clubmetro-usa.com',
#  'http://www.econtactlive.com',
#  'http://www.avanche.com',
#  'http://www.southroutt.k12.co.us',
#  'http://www.ghcpa.com',
#  'http://www.calranch.com',
#  'http://www.mallory-properties.com',
#  'http://www.emitinc.com',
#  'http://www.snwib.org',
#  'http://www.dejb.com',
#  'http://www.auduboncenter.org',
#  'http://www.ablefamilies.org',
#  'http://www.flyerie.com',
#  'http://www.advancedsecondaries.com',
#  'http://www.kgbc.com',
#  'http://www.skcs.org',
#  'http://www.hunteco.com',
#  'http://www.lifeteen.com',
#  'http://www.threeeagles.com',
#  'http://www.oasisdebendicion.org',
#  'http://www.austinrealproperty.com',
#  'http://www.reebok.com',
#  'http://www.betterbiltbuildings.com',
#  'http://www.msbna.com',
#  'http://www.cityofsacramento.org',
#  'http://www.microtellax.com',
#  'http://www.blueridge.net',
#  'http://www.greatergolf.net',
#  'http://www.avtechgroup.com',
#  'http://www.tri-cwood.com',
#  'http://www.whitneycommercial.com',
#  'http://www.ywca-minneapolis.org',
#  'http://www.alefjudaica.com',
#  'http://www.photon.com',
#  'http://www.mpls.k12.mn.us',
#  'http://www.letitsnow.com',
#  'http://www.datamatx.com',
#  'http://www.hhlutheran.org',
#  'http://www.cpyu.org',
#  'http://www.clarkart.edu',
#  'http://www.nationalauto.com',
#  'http://www.allaccess.la',
#  'http://www.charlotteengineers.com',
#  'http://www.marionstar.com',
#  'http://www.travisboatingcenter.com',
#  'http://www.tikihutsusa.com',
#  'http://www.wyattautomation.com',
#  'http://www.netflag.com',
#  'http://www.gammill.net',
#  'http://www.atozeye.com',
#  'http://www.saintpaulcity.org',
#  'http://www.karaoke-warehouse.com',
#  'http://www.crawfordtool.com',
#  'http://www.beandesign.net',
#  'http://www.bbg-bbgm.com',
#  'http://www.godfreygroup.com',
#  'http://www.weknowbeauty.com',
#  'http://www.carussos.com',
#  'http://www.noahcdc.org',
#  'http://www.leapandboundacademy.com',
#  'http://www.mid-atlanticfab.com',
#  'http://www.lsuagcenter.com',
#  'http://www.wellston.k12.ok.us',
#  'http://www.crosshatchdesign.com',
#  'http://www.superiorhomescorp.com',
#  'http://www.brininstool-lynch.com',
#  'http://www.creativeworth.com',
#  'http://www.gosuperior.net',
#  'http://www.continentalflowers.net',
#  'http://www.unitecelectronics.com',
#  'http://www.cityofhenderson.com',
#  'http://www.horsesaloon.com',
#  'http://www.advancedphoto.net',
#  'http://www.securityresources.us',
#  'http://www.goodrichsales.com',
#  'http://www.redsbarbecue.net',
#  'http://www.goldencrownmarketing.com',
#  'http://www.kraftscreens.com',
#  'http://www.servicetowing.com',
#  'http://www.msmp.net',
#  'http://www.lynnlumber.com',
#  'http://www.fleming.com',
#  'http://www.kauffmantire.com',
#  'http://www.santamarialincolnmercury.com',
#  'http://www.lbbc.org',
#  'http://www.circadesignshowroom.com',
#  'http://www.goodtms.com',
#  'http://www.servicepointusa.com',
#  'http://www.pnwtkitsap.com',
#  'http://www.columbiaautomotive.com',
#  'http://www.davis-express.com',
#  'http://www.lonemountainaviation.com',
#  'http://www.netgate.net',
#  'http://www.mcasmiramar.com',
#  'http://www.boydsltd.com',
#  'http://www.janx.net',
#  'http://www.dash1.com',
#  'http://www.sdi.com',
#  'http://www.ideacomdayton.com',
#  'http://www.secretlover.com',
#  'http://www.labordediag.com',
#  'http://www.raleybros.com',
#  'http://www.milauskas-eye.com',
#  'http://www.asbn.net',
#  'http://www.medtransone.net',
#  'http://www.quakeproofinc.com',
#  'http://www.ci.durham.nc.us',
#  'http://www.hobby-house.com',
#  'http://www.aliso.net',
#  'http://www.capefearvalley.com',
#  'http://www.drjune.com',
#  'http://www.pompominteriors.com',
#  'http://www.tntc.com',
#  'http://www.cannonmch.com',
#  'http://www.sbo.nn.k12.va.us',
#  'http://www.gap.com',
#  'http://www.avondale.k12.mi.us',
#  'http://www.rumla.com',
#  'http://www.parkcitieslaw.com',
#  'http://www.lifehammer.com',
#  'http://www.pcain.org',
#  'http://www.lanelifetrans.com',
#  'http://www.averagejoes.com',
#  'http://www.hartecars.com',
#  'http://www.cpscolor.com',
#  'http://www.lcor.com',
#  'http://www.duininckchiro.com',
#  'http://www.core-env.com',
#  'http://www.baker.edu',
#  'http://www.gochairs.com',
#  'http://www.monarchspring.com',
#  'http://www.newleafhomes.com',
#  'http://www.holgatelumber.com',
#  'http://www.gcfinc.com',
#  'http://www.metaliteind.com',
#  'http://www.sdhc.k12.fl.us',
#  'http://www.gervasioeng.com',
#  'http://www.nhworks.state.nh.us',
#  'http://www.ocanasprinting.com',
#  'http://www.eastlandclaims.com',
#  'http://www.aircontrolscience.com',
#  'http://www.industrialpumpservice.com',
#  'http://www.kirkhams.com',
#  'http://www.abbottanswering.com',
#  'http://www.marlborough-ma.gov',
#  'http://www.hopatcongschools.org',
#  'http://www.lugomfg.com',
#  'http://www.lormet.com',
#  'http://www.bassriver-inc.org',
#  'http://www.makeitelite.com',
#  'http://www.atecengineering.com',
#  'http://www.voyageur.net',
#  'http://www.northups.com',
#  'http://www.plastic.org',
#  'http://www.industrialcycles.com',
#  'http://www.ildavide.com',
#  'http://www.berrypiano.com',
#  'http://www.sandscapes.com',
#  'http://www.stevensonandsons.com',
#  'http://www.quantumforming.com',
#  'http://www.taswa.com',
#  'http://www.dunnsemails.com',
#  'http://www.fasciaschocolates.com',
#  'http://www.detrex.com',
#  'http://www.whittemorecenter.com',
#  'http://www.childrensdayton.org',
#  'http://www.bridgew.edu',
#  'http://www.palmettorehab.com',
#  'http://www.grotek.com',
#  'http://www.kendor.com',
#  'http://www.macsford.com',
#  'http://www.tgfa.com',
#  'http://www.filing-lts.com',
#  'http://www.norbertind.com',
#  'http://www.feldman-law.com',
#  'http://www.madisonwaterboard.org',
#  'http://www.delnorte.k12.ca.us',
#  'http://www.activedata.com',
#  'http://www.allianceresidentail.com',
#  'http://www.simtek.com',
#  'http://www.preventive-law.org',
#  'http://www.ci.grand-rapids.mi.us',
#  'http://www.episd.org',
#  'http://www.wrightarchitecture.com',
#  'http://www.archwaypress.com',
#  'http://www.haidawaylodge.com',
#  'http://www.wrayroofing.com',
#  'http://www.cavalierchem.com',
#  'http://www.malagamotel.com',
#  'http://www.gci.com',
#  'http://www.trueworldfoods.com',
#  'http://www.campmor.com',
#  'http://www.gowerco.com',
#  'http://www.tntmarketing.com',
#  'http://www.jetat.com',
#  'http://www.elementsinc.com',
#  'http://www.svhs.org',
#  'http://www.thechapel-nc.org',
#  'http://www.neosource.com',
#  'http://www.protekelec.com',
#  'http://www.redhotprice.com',
#  'http://www.pgus.com',
#  'http://www.richmondgalleries.com',
#  'http://www.almonassociates.com',
#  'http://www.umbra.com',
#  'http://www.elenionline.com',
#  'http://www.thamesriver.com',
#  'http://www.lamitopsail.org',
#  'http://www.cmhregional.com',
#  'http://www.holstonhome.org',
#  'http://www.pacdrill.com',
#  'http://www.hometrustbanking.com',
#  'http://www.donpenn.com',
#  'http://www.offthehooksushi.com',
#  'http://www.presscraft.com',
#  'http://www.theenergyclub.com',
#  'http://www.djj.state.com',
#  'http://www.communityspiritbank.com',
#  'http://www.montenaypower.com',
#  'http://www.lifeview.com',
#  'http://www.axicode.com',
#  'http://www.pickrelconstruction.com',
#  'http://www.imeseyecare.com',
#  'http://www.a-gant.com',
#  'http://www.youngstownlitho.com',
#  'http://www.isdsi.com',
#  'http://www.carolinamemorialbaptistchurch.org',
#  'http://www.nelsonsys.com',
#  'http://www.hydroservice.com',
#  'http://www.yourbrewery.com',
#  'http://www.softtouchphotography.com',
#  'http://www.csyonline.com',
#  'http://www.prosigns.com',
#  'http://www.moonlightspa.com',
#  'http://www.bndpa.com',
#  'http://www.martinfarms.com',
#  'http://www.integrasolutions.net',
#  'http://www.weightmanagement.wustl.edu',
#  'http://www.prestressservices.net',
#  'http://www.sicpa.com',
#  'http://www.todayscabinetry.com',
#  'http://www.bridgetownrealty.com',
#  'http://www.quietflight.com',
#  'http://www.c-s-d.org',
#  'http://www.premiumpetproducts.com',
#  'http://www.exceldryer.com',
#  'http://www.moriahfund.org',
#  'http://www.renalcaregroup.com',
#  'http://www.sheehan.com',
#  'http://www.4cpa.com',
#  'http://www.hgbc.net',
#  'http://www.fletcherthompson.com',
#  'http://www.mtsnano.com',
#  'http://www.shilconst.com',
#  'http://www.dyerelectrical.com',
#  'http://www.casesupplyinc.com',
#  ...]

# %%
count = 0
for i in range(0,len(urls)):
    if "www" in urls[i]:
        count+=1

# %%
count
# Out:
# 428284

# %%
data = None

# %%
results = []
for i in range(25650,len(urls)):
    url = urls[i]
#     print(url)
#     name = names[i]
#     print(str(i+1)+" records to be written")
    content = get_total_content(url)
#     content["_id"] = str(index[i])
#     content["name"] = str(names[i])
    content["url"] = str(url)
#     print(i)
    results.append(content)
    if (i+1)%50 == 0:
        print(str(i+1)+" records done")
        with open( 'webdata25650+.json', 'w+', encoding='utf8') as outfile1:
            json.dump(results, outfile1, indent=4, sort_keys=True, ensure_ascii=False)

# %%
with open( 'C:/Users/arvind.baranwal/Downloads/webdata3042more.json', 'w+', encoding='utf8') as outfile1:
    json.dump(results, outfile1, indent=4, sort_keys=True, ensure_ascii=False)

# %%
names[7]
# Out:
# 'Advantage Storage Company LLC'

# %%
urls[7]
# Out:
# 'http://uhaul.com'

# %%
results[0]
# Out:
# {'about': "Millcreek Tile & Stone is a commercial tile and stone installer based in Salt Lake City, Utah. Started in 2004 and built from an experienced management and installation core, Millcreek Tile & Stone focuses on commercial projects large and small.Along with our expertise in both project management and execution, we are committed to delivering a quality and durable finished product to our clients. We adhere to established TCNA and ICPI industry standards and also seek for creative and economical solutions to construction problems. We belong to the National Tile Contractors Association (NTCA) and are members of the Associated General Contractors of Utah (AGC).We specialize in any size commercial installation of porcelain and ceramic tile, stone tile, dairy and fully vitrified paving systems and interlocking concrete or stone paving systems. CSI sections 093000 ceramic tile, 096000 stone tile, and 027800 interlocking concrete (or stone) paving systems. We also install mechanically anchored stone cladding for building facades, stone fountains & planter walls and caps.If you would like to receive more information about our services, please email us and we'll get back to you, asap.HOME\nABOUT\nSERVICES\nGALLERY\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\n\nCONTACT\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\nHOME\nABOUT\nSERVICES\nGALLERY\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\n\nCONTACT\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\nHOME\nABOUT\nSERVICES\n\nGALLERY\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\n\nCONTACT\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n",
#  'home': "Since 2004, Millcreek Tile & Stone has provided the commercial construction market of Utah with expert installation of ceramic and stone tile, sand-set brick and stone pavers, dairy brick/chemical-resistant tile flooring and exterior tile as well as stone cladding.Our project management experience, professionalism, and commitment to delivering an excellent product at fair prices has made us a leader in commercial tile installation. We offer consultation to general contractors and will work with you to develop a budget for your commercial projects, large or small.If you would like to receive more information about our services, please email us and we'll get back to you, asap.HOME\nABOUT\nSERVICES\nGALLERY\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\n\nCONTACT\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\nHOME\nABOUT\nSERVICES\nGALLERY\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\n\nCONTACT\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\nHOME\nABOUT\nSERVICES\n\nGALLERY\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\n\nCONTACT\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n",
#  'meta': 'Nonewidth=device-width, initial-scale=1.0, minimum-scale=1.0, maximum-scale=1.0, user-scalable=0IE=edge,chrome=1telephone=noWordPress 4.8.2March 23, 2016August 28, 2016Millcreek TilePowered by Visual Composer - drag and drop page builder for WordPress.Jupiter 5.9.4',
#  'name': 'Millcreek Tile   &   Stone LLC',
#  'prod': "We believe in building long term working relationships with all companies that choose to use our services, acting predominantly as a Sub-Contractor our aim is to work seamlessly alongside our clients Estimators, Quantity Surveyors and Project Managers as part of the contracting team from day one.We specialize in high end impeccable quality projects, where time is of the upmost importance for our commercial clients. Our project management experience, professionalism, and commitment to delivering an excellent product at fair prices has made us a leader in commercial tile installation. We offer consultation to general contractors and will work with you to develop a budget for your commercial projects, large or small.Our Commercial Tile Installation Services:If you would like to receive more information about our services, please email us and we'll get back to you, asap.HOME\nABOUT\nSERVICES\nGALLERY\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\n\nCONTACT\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\nHOME\nABOUT\nSERVICES\nGALLERY\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\n\nCONTACT\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\nCeramic and stone tile installation\nLandscape paver installation\nMechanically anchored stone façade & planters\nDairy Brick and food processing tile flooring\nConsulting & Developing budgets for commercial projects\n\nHOME\nABOUT\nSERVICES\n\nGALLERY\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n\n\nCONTACT\n\nCERAMIC, PORCELAIN & STONE\nLANDSCAPE PAVERS\nSPECIALTY INSTALLATIONS\n",
#  'url': 'http://www.millcreektile.com'}

# %%
with open('C:/Users/arvind.baranwal/Downloads/website_to_NAICS/webdata.json',encoding='utf8') as json_file:  
    data = json.load(json_file)

# %%
len(data)
# Out:
# 30400

# %%
len(data[0:2800])
# Out:
# 2800

# %%
with open('C:/Users/arvind.baranwal/Downloads/website_to_NAICS/webdata2800+.json',encoding='utf8') as json_file:  
    data1 = json.load(json_file)

# %%
len(data1)
# Out:
# 1200

# %%
total_data = data[0:2800]+data1

# %%
len(total_data)
# Out:
# 4000

# %%
with open( 'C:/Users/arvind.baranwal/Downloads/webdata_till_4000.json', 'w+', encoding='utf8') as outfile1:
    json.dump(total_data, outfile1, indent=4, sort_keys=True, ensure_ascii=False)

# %%
data[0].keys()
# Out:
# dict_keys(['_id', 'about', 'home', 'meta', 'name', 'prod', 'url'])

# %%
import time

# %%
print("starting to measure time")
start = time.time()

results = []
for i in range(0,10):
    url = urls[i]
#     print(url)
#     name = names[i]
#     print(str(i+1)+" records to be written")
    content = get_total_content(url)
#     print(i)
    results.append(content)
# 
end = time.time()
print("time ended")

print(end - start)
# Out:
# starting to measure time
# time ended
# 468.04769134521484

# %%
from multiprocessing import Pool

# %%
urls = urls[0:10]

# %%
start = time.time()
p = Pool(10)  # Pool tells how many at a time
records = p.map(get_total_content, urls[0:1])
p.terminate()
p.join()
end = time.time()
print(end - start)

# %%
C:\Users\arvind.baranwal\Downloads\website_to_NAICS
